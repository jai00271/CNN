# %% [markdown]
# The sequential API allows you to create models layer-by-layer for most problems. It is limited in that it does not allow you to create models that share layers or have multiple inputs or outputs.
#
# The functional API in Keras is an alternate way of creating models that offers a lot more flexibility, including creating more complex models.
#
# **Keras Sequential Models**
#
# This is a way of creating deep learning models where an instance of the Sequential class is created and model layers are created and added to it.
#
# For example, the layers can be defined and passed to the Sequential as an array:
#
# ```
# from keras.models import Sequential
# from keras.layers import Dense
# model = Sequential([Dense(2, input_dim=1), Dense(1)])
# ```
#
# The Sequential model API is great for developing deep learning models in most situations, but it also has some limitations.
#
# For example, it is not straightforward to define models that may have multiple different input sources, produce multiple output destinations or models that re-use layers.
#
# **Keras Functional Models**
#
# The Keras functional API provides a more flexible way for defining models.
#
# It specifically allows you to define multiple input or output models as well as models that share layers. More than that, it allows you to define ad hoc acyclic network graphs.
#
# Models are defined by creating instances of layers and connecting them directly to each other in pairs, then defining a Model that specifies the layers to act as the input and output to the model.
#
# Source: https://machinelearningmastery.com/keras-functional-api-deep-learning/

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
print(num_classes)
# Out:
# 10

# %%
#******************* Trying to convert above via Functional API: acc ~ 84 (83.7)% ******************************

import keras
from keras import regularizers
from keras.optimizers import Adam
from keras.layers import Input
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Flatten
from keras.regularizers import l2

#Define the model

opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)

visible = Input(shape=(32, 32, 3))

conv1  = Conv2D(32, (3,3), name= 'conv1')(visible) #30
conv1 = Activation('relu')(conv1)
conv1 = BatchNormalization()(conv1)
conv1 = Dropout(0.1)(conv1)

conv2  = Conv2D(64, (3,3), padding='same', name= 'conv2')(conv1) #30
conv2  = Activation('relu')(conv2)
conv2  = BatchNormalization()(conv2)
conv2 = Dropout(0.2)(conv2)

conv3  = Conv2D(128, (3,3), padding='same', name= 'conv3')(conv2) #30
conv3  = Activation('relu')(conv3)
conv3  = BatchNormalization()(conv3)

pool1 = MaxPooling2D(pool_size=(2,2), name= 'pool1')(conv3) #15
pool1 = Dropout(0.1)(pool1)

conv4 = Convolution2D(32, (1, 1), activation="relu", name= 'conv4')(pool1) #15

conv5 = Conv2D(32, (3,3), padding='same', name= 'conv5')(conv4) #15
conv5 = Activation('relu')(conv5)
conv5 = BatchNormalization()(conv5)
conv5 = Dropout(0.2)(conv5)

conv6 = Conv2D(64, (3,3), padding='same', name= 'conv6')(conv5) #15
conv6 = Activation('relu')(conv6)
conv6 = BatchNormalization()(conv6)
conv6 = Dropout(0.1)(conv6) 

conv7 = Conv2D(128, (3,3), padding='same', name= 'conv7')(conv6) #15
conv7 = Activation('relu')(conv7)
conv7 = BatchNormalization()(conv7)

pool2 = MaxPooling2D(pool_size=(2,2), name= 'pool2')(conv7) #7
pool2 = Dropout(0.1)(pool2) 

conv8 = Convolution2D(64, (1, 1), activation="relu", name= 'conv8')(pool2) #7

conv9 = Conv2D(64, (3,3), padding='same', name= 'conv9')(conv8) #7
conv9 = Activation('relu')(conv9)
conv9 = BatchNormalization()(conv9)
conv9 = Dropout(0.2)(conv9)

conv10 = Conv2D(128, (3,3), padding='same', name= 'conv10')(conv9) #7
conv10 = Activation('relu')(conv10)
conv10 = BatchNormalization()(conv10)

conv11 = Conv2D(10, (7,7), name= 'conv11')(conv10) #1

flat = GlobalAveragePooling2D()(conv11) 
  
#flat = Flatten()(conv11)
output = Activation('softmax')(flat)
model = Model(inputs=visible, outputs=output)
 
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])

#summarize layers
print(model.summary())

#plot graph
plot_model(model, to_file='model_plot.jpg', show_shapes=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0711 11:06:44.425331 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0711 11:06:44.426537 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0711 11:06:44.428696 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0711 11:06:44.469657 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0711 11:06:44.470674 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0711 11:06:47.264791 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0711 11:06:47.430668 140629106624384 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0711 11:06:47.651800 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0711 11:06:48.204370 140629106624384 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 30, 30, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 30, 30, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 30, 30, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 30, 30, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 30, 30, 128)       512
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 15, 128)       0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 15, 15, 32)        4128
# _________________________________________________________________
# conv5 (Conv2D)               (None, 15, 15, 32)        9248
# _________________________________________________________________
# activation_4 (Activation)    (None, 15, 15, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 15, 15, 32)        128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_5 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 15, 15, 128)       73856
# _________________________________________________________________
# activation_6 (Activation)    (None, 15, 15, 128)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 15, 15, 128)       512
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 7, 7, 64)          8256
# _________________________________________________________________
# conv9 (Conv2D)               (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_7 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 7, 7, 128)         73856
# _________________________________________________________________
# activation_8 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# conv11 (Conv2D)              (None, 1, 1, 10)          62730
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 10)                0
# _________________________________________________________________
# activation_9 (Activation)    (None, 10)                0
# =================================================================
# Total params: 383,306
# Trainable params: 382,026
# Non-trainable params: 1,280
# _________________________________________________________________
# None

# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ModelCheckpoint

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)

# Accuracy on test data is: 83.88
# def scheduler(epoch, lr):
#   return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# Accuracy on test data is: 83.48
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate

# filepath="model_accuracy.best.hdf5"

filepath='/content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5'

reduce_LR = LearningRateScheduler(lr_schedule, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 64),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 75, 
                                 validation_data = (test_features, test_labels), verbose=1,
                                callbacks=[reduce_LR, checkpoint])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=781, epochs=75)`
# W0711 11:07:51.445340 140629106624384 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/75
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 30s 38ms/step - loss: 1.8033 - acc: 0.4451 - val_loss: 2.0956 - val_acc: 0.4990
#
# Epoch 00001: val_acc improved from -inf to 0.49900, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 2/75
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 1.0330 - acc: 0.6526 - val_loss: 0.9475 - val_acc: 0.6897
#
# Epoch 00002: val_acc improved from 0.49900 to 0.68970, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 3/75
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7912 - acc: 0.7290 - val_loss: 0.7883 - val_acc: 0.7390
#
# Epoch 00003: val_acc improved from 0.68970 to 0.73900, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 4/75
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.6669 - acc: 0.7717 - val_loss: 1.1566 - val_acc: 0.6186
#
# Epoch 00004: val_acc did not improve from 0.73900
# Epoch 5/75
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5803 - acc: 0.7995 - val_loss: 0.7252 - val_acc: 0.7535
#
# Epoch 00005: val_acc improved from 0.73900 to 0.75350, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 6/75
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.5160 - acc: 0.8214 - val_loss: 0.7569 - val_acc: 0.7714
#
# Epoch 00006: val_acc improved from 0.75350 to 0.77140, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 7/75
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4681 - acc: 0.8389 - val_loss: 0.6250 - val_acc: 0.7925
#
# Epoch 00007: val_acc improved from 0.77140 to 0.79250, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 8/75
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4251 - acc: 0.8519 - val_loss: 0.6272 - val_acc: 0.7966
#
# Epoch 00008: val_acc improved from 0.79250 to 0.79660, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 9/75
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.3938 - acc: 0.8627 - val_loss: 0.6531 - val_acc: 0.7910
#
# Epoch 00009: val_acc did not improve from 0.79660
# Epoch 10/75
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.3570 - acc: 0.8730 - val_loss: 0.6191 - val_acc: 0.8093
#
# Epoch 00010: val_acc improved from 0.79660 to 0.80930, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 11/75
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.3356 - acc: 0.8832 - val_loss: 0.6857 - val_acc: 0.7883
#
# Epoch 00011: val_acc did not improve from 0.80930
# Epoch 12/75
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.3083 - acc: 0.8918 - val_loss: 0.6610 - val_acc: 0.8065
#
# Epoch 00012: val_acc did not improve from 0.80930
# Epoch 13/75
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.2894 - acc: 0.9001 - val_loss: 0.6216 - val_acc: 0.8050
#
# Epoch 00013: val_acc did not improve from 0.80930
# Epoch 14/75
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.2739 - acc: 0.9024 - val_loss: 0.6279 - val_acc: 0.8086
#
# Epoch 00014: val_acc did not improve from 0.80930
# Epoch 15/75
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.2568 - acc: 0.9090 - val_loss: 0.6764 - val_acc: 0.8161
#
# Epoch 00015: val_acc improved from 0.80930 to 0.81610, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 16/75
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.2377 - acc: 0.9155 - val_loss: 0.6616 - val_acc: 0.8061
#
# Epoch 00016: val_acc did not improve from 0.81610
# Epoch 17/75
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.2264 - acc: 0.9201 - val_loss: 0.6657 - val_acc: 0.8095
#
# Epoch 00017: val_acc did not improve from 0.81610
# Epoch 18/75
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.2183 - acc: 0.9218 - val_loss: 0.6374 - val_acc: 0.8238
#
# Epoch 00018: val_acc improved from 0.81610 to 0.82380, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 19/75
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.2023 - acc: 0.9276 - val_loss: 0.6565 - val_acc: 0.8228
#
# Epoch 00019: val_acc did not improve from 0.82380
# Epoch 20/75
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1911 - acc: 0.9317 - val_loss: 0.7073 - val_acc: 0.8136
#
# Epoch 00020: val_acc did not improve from 0.82380
# Epoch 21/75
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1801 - acc: 0.9353 - val_loss: 0.6762 - val_acc: 0.8206
#
# Epoch 00021: val_acc did not improve from 0.82380
# Epoch 22/75
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1775 - acc: 0.9357 - val_loss: 0.7136 - val_acc: 0.8117
#
# Epoch 00022: val_acc did not improve from 0.82380
# Epoch 23/75
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1689 - acc: 0.9388 - val_loss: 0.7183 - val_acc: 0.8175
#
# Epoch 00023: val_acc did not improve from 0.82380
# Epoch 24/75
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1661 - acc: 0.9403 - val_loss: 0.7217 - val_acc: 0.8187
#
# Epoch 00024: val_acc did not improve from 0.82380
# Epoch 25/75
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1605 - acc: 0.9431 - val_loss: 0.7296 - val_acc: 0.8204
#
# Epoch 00025: val_acc did not improve from 0.82380
# Epoch 26/75
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1552 - acc: 0.9433 - val_loss: 0.7418 - val_acc: 0.8138
#
# Epoch 00026: val_acc did not improve from 0.82380
# Epoch 27/75
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1465 - acc: 0.9475 - val_loss: 0.7312 - val_acc: 0.8234
#
# Epoch 00027: val_acc did not improve from 0.82380
# Epoch 28/75
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1389 - acc: 0.9497 - val_loss: 0.6936 - val_acc: 0.8283
#
# Epoch 00028: val_acc improved from 0.82380 to 0.82830, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 29/75
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1380 - acc: 0.9496 - val_loss: 0.7355 - val_acc: 0.8218
#
# Epoch 00029: val_acc did not improve from 0.82830
# Epoch 30/75
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1365 - acc: 0.9516 - val_loss: 0.7408 - val_acc: 0.8215
#
# Epoch 00030: val_acc did not improve from 0.82830
# Epoch 31/75
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1310 - acc: 0.9535 - val_loss: 0.7266 - val_acc: 0.8193
#
# Epoch 00031: val_acc did not improve from 0.82830
# Epoch 32/75
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1277 - acc: 0.9545 - val_loss: 0.7779 - val_acc: 0.8175
#
# Epoch 00032: val_acc did not improve from 0.82830
# Epoch 33/75
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1253 - acc: 0.9551 - val_loss: 0.7445 - val_acc: 0.8188
#
# Epoch 00033: val_acc did not improve from 0.82830
# Epoch 34/75
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.1225 - acc: 0.9564 - val_loss: 0.7736 - val_acc: 0.8250
#
# Epoch 00034: val_acc did not improve from 0.82830
# Epoch 35/75
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.1171 - acc: 0.9586 - val_loss: 0.7282 - val_acc: 0.8312
#
# Epoch 00035: val_acc improved from 0.82830 to 0.83120, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 36/75
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1184 - acc: 0.9580 - val_loss: 0.7330 - val_acc: 0.8287
#
# Epoch 00036: val_acc did not improve from 0.83120
# Epoch 37/75
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.1118 - acc: 0.9599 - val_loss: 0.8107 - val_acc: 0.8180
#
# Epoch 00037: val_acc did not improve from 0.83120
# Epoch 38/75
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.1103 - acc: 0.9602 - val_loss: 0.7317 - val_acc: 0.8313
#
# Epoch 00038: val_acc improved from 0.83120 to 0.83130, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 39/75
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.1071 - acc: 0.9618 - val_loss: 0.8069 - val_acc: 0.8176
#
# Epoch 00039: val_acc did not improve from 0.83130
# Epoch 40/75
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.1051 - acc: 0.9625 - val_loss: 0.7474 - val_acc: 0.8300
#
# Epoch 00040: val_acc did not improve from 0.83130
# Epoch 41/75
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.1039 - acc: 0.9626 - val_loss: 0.7877 - val_acc: 0.8231
#
# Epoch 00041: val_acc did not improve from 0.83130
# Epoch 42/75
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.1011 - acc: 0.9648 - val_loss: 0.7650 - val_acc: 0.8271
#
# Epoch 00042: val_acc did not improve from 0.83130
# Epoch 43/75
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0975 - acc: 0.9653 - val_loss: 0.7596 - val_acc: 0.8332
#
# Epoch 00043: val_acc improved from 0.83130 to 0.83320, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 44/75
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0966 - acc: 0.9664 - val_loss: 0.8367 - val_acc: 0.8262
#
# Epoch 00044: val_acc did not improve from 0.83320
# Epoch 45/75
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0912 - acc: 0.9676 - val_loss: 0.7761 - val_acc: 0.8336
#
# Epoch 00045: val_acc improved from 0.83320 to 0.83360, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 46/75
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0926 - acc: 0.9671 - val_loss: 0.7713 - val_acc: 0.8327
#
# Epoch 00046: val_acc did not improve from 0.83360
# Epoch 47/75
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0901 - acc: 0.9676 - val_loss: 0.7693 - val_acc: 0.8378
#
# Epoch 00047: val_acc improved from 0.83360 to 0.83780, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 48/75
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0895 - acc: 0.9679 - val_loss: 0.7708 - val_acc: 0.8383
#
# Epoch 00048: val_acc improved from 0.83780 to 0.83830, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 49/75
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0865 - acc: 0.9699 - val_loss: 0.8054 - val_acc: 0.8322
#
# Epoch 00049: val_acc did not improve from 0.83830
# Epoch 50/75
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0864 - acc: 0.9687 - val_loss: 0.8019 - val_acc: 0.8295
#
# Epoch 00050: val_acc did not improve from 0.83830
# Epoch 51/75
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0845 - acc: 0.9692 - val_loss: 0.7748 - val_acc: 0.8423
#
# Epoch 00051: val_acc improved from 0.83830 to 0.84230, saving model to /content/drive/My Drive/Colab Notebooks/9. Data Augmentation/model_accuracy.best.hdf5
# Epoch 52/75
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0843 - acc: 0.9710 - val_loss: 0.7991 - val_acc: 0.8276
#
# Epoch 00052: val_acc did not improve from 0.84230
# Epoch 53/75
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0854 - acc: 0.9695 - val_loss: 0.8092 - val_acc: 0.8307
#
# Epoch 00053: val_acc did not improve from 0.84230
# Epoch 54/75
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0840 - acc: 0.9706 - val_loss: 0.7882 - val_acc: 0.8359
#
# Epoch 00054: val_acc did not improve from 0.84230
# Epoch 55/75
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0839 - acc: 0.9710 - val_loss: 0.8025 - val_acc: 0.8357
#
# Epoch 00055: val_acc did not improve from 0.84230
# Epoch 56/75
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0838 - acc: 0.9703 - val_loss: 0.7876 - val_acc: 0.8328
#
# Epoch 00056: val_acc did not improve from 0.84230
# Epoch 57/75
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0776 - acc: 0.9727 - val_loss: 0.7822 - val_acc: 0.8393
#
# Epoch 00057: val_acc did not improve from 0.84230
# Epoch 58/75
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0745 - acc: 0.9736 - val_loss: 0.8302 - val_acc: 0.8273
#
# Epoch 00058: val_acc did not improve from 0.84230
# Epoch 59/75
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0744 - acc: 0.9742 - val_loss: 0.8032 - val_acc: 0.8331
#
# Epoch 00059: val_acc did not improve from 0.84230
# Epoch 60/75
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0781 - acc: 0.9732 - val_loss: 0.8096 - val_acc: 0.8338
#
# Epoch 00060: val_acc did not improve from 0.84230
# Epoch 61/75
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0747 - acc: 0.9726 - val_loss: 0.8197 - val_acc: 0.8422
#
# Epoch 00061: val_acc did not improve from 0.84230
# Epoch 62/75
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0708 - acc: 0.9755 - val_loss: 0.8085 - val_acc: 0.8332
#
# Epoch 00062: val_acc did not improve from 0.84230
# Epoch 63/75
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0740 - acc: 0.9743 - val_loss: 0.8352 - val_acc: 0.8315
#
# Epoch 00063: val_acc did not improve from 0.84230
# Epoch 64/75
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0701 - acc: 0.9756 - val_loss: 0.8087 - val_acc: 0.8372
#
# Epoch 00064: val_acc did not improve from 0.84230
# Epoch 65/75
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0679 - acc: 0.9767 - val_loss: 0.8583 - val_acc: 0.8318
#
# Epoch 00065: val_acc did not improve from 0.84230
# Epoch 66/75
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 24s 31ms/step - loss: 0.0685 - acc: 0.9760 - val_loss: 0.8305 - val_acc: 0.8365
#
# Epoch 00066: val_acc did not improve from 0.84230
# Epoch 67/75
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0699 - acc: 0.9756 - val_loss: 0.8247 - val_acc: 0.8370
#
# Epoch 00067: val_acc did not improve from 0.84230
# Epoch 68/75
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 24s 31ms/step - loss: 0.0668 - acc: 0.9767 - val_loss: 0.8129 - val_acc: 0.8354
#
# Epoch 00068: val_acc did not improve from 0.84230
# Epoch 69/75
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0712 - acc: 0.9751 - val_loss: 0.7946 - val_acc: 0.8349
#
# Epoch 00069: val_acc did not improve from 0.84230
# Epoch 70/75
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0674 - acc: 0.9766 - val_loss: 0.8515 - val_acc: 0.8336
#
# Epoch 00070: val_acc did not improve from 0.84230
# Epoch 71/75
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0671 - acc: 0.9768 - val_loss: 0.8240 - val_acc: 0.8407
#
# Epoch 00071: val_acc did not improve from 0.84230
# Epoch 72/75
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0688 - acc: 0.9768 - val_loss: 0.8121 - val_acc: 0.8420
#
# Epoch 00072: val_acc did not improve from 0.84230
# Epoch 73/75
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0640 - acc: 0.9772 - val_loss: 0.8230 - val_acc: 0.8382
#
# Epoch 00073: val_acc did not improve from 0.84230
# Epoch 74/75
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0627 - acc: 0.9785 - val_loss: 0.8327 - val_acc: 0.8335
#
# Epoch 00074: val_acc did not improve from 0.84230
# Epoch 75/75
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.001.
# 781/781 [==============================] - 25s 31ms/step - loss: 0.0635 - acc: 0.9779 - val_loss: 0.9047 - val_acc: 0.8327
#
# Epoch 00075: val_acc did not improve from 0.84230
# Model took 1865.61 seconds to train
# Accuracy on test data is: 83.27
